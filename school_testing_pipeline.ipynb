# %% [markdown]
# ## California School Testing
#
# The data is California Assessment of Student Performance and Progress (CAASPP) Smarter Balanced Assessments released by the California Department of Education (link: https://caaspp.cde.ca.gov/sb2018/ResearchFileList)

# %%
import requests

## Retrieve Smarter Balanced Assessments Statewide results and save in the data directory
input_filenames = ['sb_ca2018_1_csv_v3.zip',
                   'sb_ca2017_1_csv_v2.zip',
                   'sb_ca2016_1_csv_v3.zip',
                   'sb_ca2015_1_csv_v3.zip']

for fn in input_filenames:
    url = 'http://www3.cde.ca.gov/caasppresearchfiles/2018/sb/' + fn
    year = fn[5:9]
    outfilename = 'data/{}.zip'.format(fn[:9])
    print('url, outfilename: ', url, outfilename)
    r = requests.get(url, allow_redirects=True)
    open(outfilename, 'wb').write(r.content)
    
## Retrieve the latest entity file, because we want to analyze the data to make decisions about current schools
url = 'http://www3.cde.ca.gov/caasppresearchfiles/2018/sb/sb_ca2018entities_csv.zip'
outfilename = 'data/ca_entities.zip'
r = requests.get(url, allow_redirects=True)
open(outfilename, 'wb').write(r.content)
# Out:
# url, outfilename:  http://www3.cde.ca.gov/caasppresearchfiles/2018/sb/sb_ca2018_1_csv_v3.zip data/sb_ca2018.zip
# url, outfilename:  http://www3.cde.ca.gov/caasppresearchfiles/2018/sb/sb_ca2017_1_csv_v2.zip data/sb_ca2017.zip
# url, outfilename:  http://www3.cde.ca.gov/caasppresearchfiles/2018/sb/sb_ca2016_1_csv_v3.zip data/sb_ca2016.zip
# url, outfilename:  http://www3.cde.ca.gov/caasppresearchfiles/2018/sb/sb_ca2015_1_csv_v3.zip data/sb_ca2015.zip
# 188963

# %%
import os
import re
import pandas as pd
from zipfile import ZipFile

input_dir = 'data'
zip_filenames = sorted([input_dir + '/' + filename for filename in os.listdir(input_dir) if re.match('sb_ca\d+.zip', filename)], reverse=True)
test_result_dfs = []
for zip_fn in zip_filenames:
    print(zip_fn)
    zip_file = ZipFile(zip_fn)
    
    for text_file in zip_file.infolist():
        if 'entities' not in text_file.filename:
            df = pd.read_csv(zip_file.open(text_file.filename))
            if ('2016' in zip_fn or '2015' in zip_fn):
                df.drop(['Total CAASPP Enrollment'], axis=1, inplace=True)
            test_result_dfs.append(df)
            break

# realign column names
for df in test_result_dfs:
    df.columns = [col.replace('At or Near', 'Near')
                                 .replace('Total Tested at Subgroup Level', 'Total Tested with Scores') 
                              for col in df.columns]
combined_df = pd.concat(test_result_dfs, axis=0, ignore_index=True, sort=False)
combined_df.shape
# Out:
# data/sb_ca2018.zip
# data/sb_ca2017.zip
# data/sb_ca2016.zip
# data/sb_ca2015.zip
# (408291, 32)

# %%
## entity is defined by CDS_CODE, which is composed of county code, district code, and school code
## each row has a unique CDS_CODE + Grade + Test Id
test_id_lkup_list = ['', 'SB - English Language Arts/Literacy', 'SB - Mathematics']
combined_df["CDS_CODE"] = (combined_df["County Code"].astype(str).str.pad(2, 'left', '0')
                  + combined_df["District Code"].astype(str).str.pad(5, 'left', '0') 
                  + combined_df["School Code"].astype(str).str.pad(7, 'left', '0')
                 )
columns_to_drop = ['Filler', 'Subgroup ID','Test Type'] + [col for col in combined_df.columns if col.startswith('Area ')]
combined_df["Test Name"] = combined_df["Test Id"].apply(lambda x:test_id_lkup_list[x])
combined_df.drop(columns_to_drop, axis=1, inplace=True)
combined_df.head().T
# Out:
#                                                                      0  \
# CDS_CODE                                                00000000000000
# County Code                                                          0
# District Code                                                        0
# School Code                                                          0
# Test Year                                                         2018
# Total Tested At Entity Level                                   3180571
# Total Tested with Scores                                       3177420
# Grade                                                                3
# Test Id                                                              1
# CAASPP Reported Enrollment                                      445017
# Students Tested                                                 434468
# Mean Scale Score                                                2424.0
# Percentage Standard Exceeded                                     26.13
# Percentage Standard Met                                          22.09
# Percentage Standard Met and Above                                48.22
# Percentage Standard Nearly Met                                   23.49
# Percentage Standard Not Met                                      28.29
# Students with Scores                                            434207
# Test Name                          SB - English Language Arts/Literacy
#
#                                                   1                 2  \
# CDS_CODE                             00000000000000    00000000000000
# County Code                                       0                 0
# District Code                                     0                 0
# School Code                                       0                 0
# Test Year                                      2018              2018
# Total Tested At Entity Level                3187408           3187408
# Total Tested with Scores                    3184720           3184720
# Grade                                             3                 4
# Test Id                                           2                 2
# CAASPP Reported Enrollment                   445018            463838
# Students Tested                              436464            455619
# Mean Scale Score                             2430.9            2467.7
# Percentage Standard Exceeded                  21.07             18.46
# Percentage Standard Met                       27.82             24.45
# Percentage Standard Met and Above             48.89             42.91
# Percentage Standard Nearly Met                23.56             30.81
# Percentage Standard Not Met                   27.55             26.27
# Students with Scores                         436215            455345
# Test Name                          SB - Mathematics  SB - Mathematics
#
#                                                                      3  \
# CDS_CODE                                                00000000000000
# County Code                                                          0
# District Code                                                        0
# School Code                                                          0
# Test Year                                                         2018
# Total Tested At Entity Level                                   3180571
# Total Tested with Scores                                       3177420
# Grade                                                                4
# Test Id                                                              1
# CAASPP Reported Enrollment                                      463838
# Students Tested                                                 453771
# Mean Scale Score                                                2463.7
# Percentage Standard Exceeded                                     26.31
# Percentage Standard Met                                          22.36
# Percentage Standard Met and Above                                48.67
# Percentage Standard Nearly Met                                   19.25
# Percentage Standard Not Met                                      32.08
# Students with Scores                                            453491
# Test Name                          SB - English Language Arts/Literacy
#
#                                                                      4
# CDS_CODE                                                00000000000000
# County Code                                                          0
# District Code                                                        0
# School Code                                                          0
# Test Year                                                         2018
# Total Tested At Entity Level                                   3180571
# Total Tested with Scores                                       3177420
# Grade                                                                5
# Test Id                                                              1
# CAASPP Reported Enrollment                                      469247
# Students Tested                                                 459434
# Mean Scale Score                                                2496.3
# Percentage Standard Exceeded                                     21.80
# Percentage Standard Met                                          27.63
# Percentage Standard Met and Above                                49.43
# Percentage Standard Nearly Met                                   19.99
# Percentage Standard Not Met                                      30.58
# Students with Scores                                            459209
# Test Name                          SB - English Language Arts/Literacy

# %% [markdown]
# ## Read the entities file

# %%
zip_fn = 'data/ca_entities.zip'
encoding = "ISO-8859-1"
df = pd.read_csv(zip_fn, encoding=encoding)
df.head()
# Out:
#    County Code  District Code  School Code  Filler  Test Year  Type Id  \
# 0            0              0            0     NaN       2018        4
# 1            1              0            0     NaN       2018        5
# 2            1          10017            0     NaN       2018        6
# 3            1          10017       112607     NaN       2018        9
# 4            1          10017       123968     NaN       2018        9
#
#            County Name                            District Name  \
# 0  State of California                                      NaN
# 1              Alameda                                      NaN
# 2              Alameda       Alameda County Office Of Education
# 3              Alameda   Envision Academy For Arts & Technology
# 4              Alameda  Community School For Creative Education
#
#                                School Name Zip Code
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3   Envision Academy For Arts & Technology    94612
# 4  Community School For Creative Education    94606

# %% [markdown]
# Type ID:
# * 4: Data is aggregated at the state level
# * 5: Data is aggregated at the county level
# * 6: Data is aggregated at the school district level
# * 7: Data is aggregated at the public school level
# * 9: Public charter school that receives funds directly from the state
# * 10: Public charter school that receives funds from the school district

# %%
df["CDS_CODE"] = (df["County Code"].astype(str).str.pad(2, 'left', '0')
                  + df["District Code"].astype(str).str.pad(5, 'left', '0') 
                  + df["School Code"].astype(str).str.pad(7, 'left', '0')
                 )
type_id_dict = {4:'State', 5: 'County', 6: 'School District', 7:'Public School', 9:'State Funded Charter', 10:'District Funded Charter'}
df["Entity Type"] = df["Type Id"].apply(lambda x:type_id_dict[x])
df["School Name"] = df["School Name"].fillna("N/A")
df["District Name"] = df["District Name"].fillna("N/A")
df["County Name"] = df["County Name"].fillna("N/A")
df.head()
# Out:
#    County Code  District Code  School Code  Filler  Test Year  Type Id  \
# 0            0              0            0     NaN       2018        4
# 1            1              0            0     NaN       2018        5
# 2            1          10017            0     NaN       2018        6
# 3            1          10017       112607     NaN       2018        9
# 4            1          10017       123968     NaN       2018        9
#
#            County Name                            District Name  \
# 0  State of California                                      N/A
# 1              Alameda                                      N/A
# 2              Alameda       Alameda County Office Of Education
# 3              Alameda   Envision Academy For Arts & Technology
# 4              Alameda  Community School For Creative Education
#
#                                School Name Zip Code        CDS_CODE  \
# 0                                      N/A           00000000000000
# 1                                      N/A           01000000000000
# 2                                      N/A           01100170000000
# 3   Envision Academy For Arts & Technology    94612  01100170112607
# 4  Community School For Creative Education    94606  01100170123968
#
#             Entity Type
# 0                 State
# 1                County
# 2       School District
# 3  State Funded Charter
# 4  State Funded Charter

# %%
# output the cleaned up entity file
df.drop(['Filler', 'Type Id'], axis=1, inplace=True)
df.to_csv(input_dir + "/" +'ca_entities_clean.csv')

# %% [markdown]
# ## Split up the test result df into multiple files by entity type

# %%
df['Test Year'].value_counts()
# Out:
# 2018    11333
# Name: Test Year, dtype: int64

# %%
print("Shape before merge: ", combined_df.shape)
combined_df2 = pd.merge(combined_df, df.drop(['Test Year', 'County Code', 'District Code', 'School Code'], axis=1), how='inner', on=['CDS_CODE'])
print("Shape after merge: ", combined_df2.shape)
# Out:
# Shape before merge:  (408291, 19)
# Shape after merge:  (392991, 24)

# %%
print("Records retained after merge: {:.2%}".format(combined_df2.shape[0]/combined_df.shape[0]))
# Out:
# Records retained after merge: 96.25%

# %%
combined_df2.replace('*', '', inplace=True)

# %%
combined_df2.to_csv(input_dir + "/" +'ca_smarter_balance_results_combined.csv')

# %%
combined_df2[combined_df2['CDS_CODE'] == '41688666043475'].T
# Out:
#                                                                 304596  \
# CDS_CODE                                                41688666043475
# County Code                                                         41
# District Code                                                    68866
# School Code                                                    6043475
# Test Year                                                         2018
# Total Tested At Entity Level                                       356
# Total Tested with Scores                                           356
# Grade                                                                3
# Test Id                                                              2
# CAASPP Reported Enrollment                                          73
# Students Tested                                                     73
# Mean Scale Score                                                2490.4
# Percentage Standard Exceeded                                     46.58
# Percentage Standard Met                                          28.77
# Percentage Standard Met and Above                                75.34
# Percentage Standard Nearly Met                                   19.18
# Percentage Standard Not Met                                       5.48
# Students with Scores                                                73
# Test Name                          SB - English Language Arts/Literacy
# County Name                                                  San Mateo
# District Name                        Belmont-Redwood Shores Elementary
# School Name                                          Nesbit Elementary
# Zip Code                                                         94002
# Entity Type                                              Public School
#
#                                                               304597  \
# CDS_CODE                                              41688666043475
# County Code                                                       41
# District Code                                                  68866
# School Code                                                  6043475
# Test Year                                                       2018
# Total Tested At Entity Level                                     349
# Total Tested with Scores                                         349
# Grade                                                              3
# Test Id                                                            1
# CAASPP Reported Enrollment                                        73
# Students Tested                                                   71
# Mean Scale Score                                              2491.0
# Percentage Standard Exceeded                                   46.48
# Percentage Standard Met                                        35.21
# Percentage Standard Met and Above                              81.69
# Percentage Standard Nearly Met                                 18.31
# Percentage Standard Not Met                                     0.00
# Students with Scores                                              71
# Test Name                                           SB - Mathematics
# County Name                                                San Mateo
# District Name                      Belmont-Redwood Shores Elementary
# School Name                                        Nesbit Elementary
# Zip Code                                                       94002
# Entity Type                                            Public School
#
#                                                               304598  \
# CDS_CODE                                              41688666043475
# County Code                                                       41
# District Code                                                  68866
# School Code                                                  6043475
# Test Year                                                       2018
# Total Tested At Entity Level                                     356
# Total Tested with Scores                                         356
# Grade                                                              4
# Test Id                                                            2
# CAASPP Reported Enrollment                                        84
# Students Tested                                                   82
# Mean Scale Score                                              2540.2
# Percentage Standard Exceeded                                   51.22
# Percentage Standard Met                                        25.61
# Percentage Standard Met and Above                              76.83
# Percentage Standard Nearly Met                                 15.85
# Percentage Standard Not Met                                     7.32
# Students with Scores                                              82
# Test Name                                           SB - Mathematics
# County Name                                                San Mateo
# District Name                      Belmont-Redwood Shores Elementary
# School Name                                        Nesbit Elementary
# Zip Code                                                       94002
# Entity Type                                            Public School
#
#                                                                 304599  \
# CDS_CODE                                                41688666043475
# County Code                                                         41
# District Code                                                    68866
# School Code                                                    6043475
# Test Year                                                         2018
# Total Tested At Entity Level                                       349
# Total Tested with Scores                                           349
# Grade                                                                4
# Test Id                                                              1
# CAASPP Reported Enrollment                                          84
# Students Tested                                                     80
# Mean Scale Score                                                2546.3
# Percentage Standard Exceeded                                     57.50
# Percentage Standard Met                                          20.00
# Percentage Standard Met and Above                                77.50
# Percentage Standard Nearly Met                                   13.75
# Percentage Standard Not Met                                       8.75
# Students with Scores                                                80
# Test Name                          SB - English Language Arts/Literacy
# County Name                                                  San Mateo
# District Name                        Belmont-Redwood Shores Elementary
# School Name                                          Nesbit Elementary
# Zip Code                                                         94002
# Entity Type                                              Public School
#
#                                                                 304600  \
# CDS_CODE                                                41688666043475
# County Code                                                         41
# District Code                                                    68866
# School Code                                                    6043475
# Test Year                                                         2018
# Total Tested At Entity Level                                       356
# Total Tested with Scores                                           356
# Grade                                                                5
# Test Id                                                              2
# CAASPP Reported Enrollment                                          73
# Students Tested                                                     71
# Mean Scale Score                                                2548.9
# Percentage Standard Exceeded                                     40.85
# Percentage Standard Met                                          12.68
# Percentage Standard Met and Above                                53.52
# Percentage Standard Nearly Met                                   28.17
# Percentage Standard Not Met                                      18.31
# Students with Scores                                                71
# Test Name                          SB - English Language Arts/Literacy
# County Name                                                  San Mateo
# District Name                        Belmont-Redwood Shores Elementary
# School Name                                          Nesbit Elementary
# Zip Code                                                         94002
# Entity Type                                              Public School
#
#                                                               304601  \
# CDS_CODE                                              41688666043475
# County Code                                                       41
# District Code                                                  68866
# School Code                                                  6043475
# Test Year                                                       2018
# Total Tested At Entity Level                                     349
# Total Tested with Scores                                         349
# Grade                                                              5
# Test Id                                                            1
# CAASPP Reported Enrollment                                        73
# Students Tested                                                   70
# Mean Scale Score                                              2555.3
# Percentage Standard Exceeded                                   45.71
# Percentage Standard Met                                        24.29
# Percentage Standard Met and Above                              70.00
# Percentage Standard Nearly Met                                 14.29
# Percentage Standard Not Met                                    15.71
# Students with Scores                                              70
# Test Name                                           SB - Mathematics
# County Name                                                San Mateo
# District Name                      Belmont-Redwood Shores Elementary
# School Name                                        Nesbit Elementary
# Zip Code                                                       94002
# Entity Type                                            Public School
#
#                                                               304602  \
# CDS_CODE                                              41688666043475
# County Code                                                       41
# District Code                                                  68866
# School Code                                                  6043475
# Test Year                                                       2018
# Total Tested At Entity Level                                     356
# Total Tested with Scores                                         356
# Grade                                                              6
# Test Id                                                            2
# CAASPP Reported Enrollment                                        44
# Students Tested                                                   42
# Mean Scale Score                                              2528.1
# Percentage Standard Exceeded                                   21.43
# Percentage Standard Met                                        19.05
# Percentage Standard Met and Above                              40.48
# Percentage Standard Nearly Met                                 33.33
# Percentage Standard Not Met                                    26.19
# Students with Scores                                              42
# Test Name                                           SB - Mathematics
# County Name                                                San Mateo
# District Name                      Belmont-Redwood Shores Elementary
# School Name                                        Nesbit Elementary
# Zip Code                                                       94002
# Entity Type                                            Public School
#
#                                                                 304603  \
# CDS_CODE                                                41688666043475
# County Code                                                         41
# District Code                                                    68866
# School Code                                                    6043475
# Test Year                                                         2018
# Total Tested At Entity Level                                       349
# Total Tested with Scores                                           349
# Grade                                                                6
# Test Id                                                              1
# CAASPP Reported Enrollment                                          44
# Students Tested                                                     41
# Mean Scale Score                                                2544.0
# Percentage Standard Exceeded                                     24.39
# Percentage Standard Met                                          34.15
# Percentage Standard Met and Above                                58.54
# Percentage Standard Nearly Met                                   24.39
# Percentage Standard Not Met                                      17.07
# Students with Scores                                                41
# Test Name                          SB - English Language Arts/Literacy
# County Name                                                  San Mateo
# District Name                        Belmont-Redwood Shores Elementary
# School Name                                          Nesbit Elementary
# Zip Code                                                         94002
# Entity Type                                              Public School
#
#                                                                 304604  \
# CDS_CODE                                                41688666043475
# County Code                                                         41
# District Code                                                    68866
# School Code                                                    6043475
# Test Year                                                         2018
# Total Tested At Entity Level                                       356
# Total Tested with Scores                                           356
# Grade                                                                7
# Test Id                                                              2
# CAASPP Reported Enrollment                                          51
# Students Tested                                                     50
# Mean Scale Score                                                2599.1
# Percentage Standard Exceeded                                     38.00
# Percentage Standard Met                                          32.00
# Percentage Standard Met and Above                                70.00
# Percentage Standard Nearly Met                                   20.00
# Percentage Standard Not Met                                      10.00
# Students with Scores                                                50
# Test Name                          SB - English Language Arts/Literacy
# County Name                                                  San Mateo
# District Name                        Belmont-Redwood Shores Elementary
# School Name                                          Nesbit Elementary
# Zip Code                                                         94002
# Entity Type                                              Public School
#
#                                                               304605  ...  \
# CDS_CODE                                              41688666043475  ...
# County Code                                                       41  ...
# District Code                                                  68866  ...
# School Code                                                  6043475  ...
# Test Year                                                       2018  ...
# Total Tested At Entity Level                                     349  ...
# Total Tested with Scores                                         349  ...
# Grade                                                              7  ...
# Test Id                                                            1  ...
# CAASPP Reported Enrollment                                        51  ...
# Students Tested                                                   50  ...
# Mean Scale Score                                              2603.7  ...
# Percentage Standard Exceeded                                   34.00  ...
# Percentage Standard Met                                        34.00  ...
# Percentage Standard Met and Above                              68.00  ...
# Percentage Standard Nearly Met                                 24.00  ...
# Percentage Standard Not Met                                     8.00  ...
# Students with Scores                                              50  ...
# Test Name                                           SB - Mathematics  ...
# County Name                                                San Mateo  ...
# District Name                      Belmont-Redwood Shores Elementary  ...
# School Name                                        Nesbit Elementary  ...
# Zip Code                                                       94002  ...
# Entity Type                                            Public School  ...
#
#                                                               304630  \
# CDS_CODE                                              41688666043475
# County Code                                                       41
# District Code                                                  68866
# School Code                                                  6043475
# Test Year                                                       2016
# Total Tested At Entity Level                                     226
# Total Tested with Scores                                         226
# Grade                                                             13
# Test Id                                                            2
# CAASPP Reported Enrollment                                       230
# Students Tested                                                  226
# Mean Scale Score                                                 NaN
# Percentage Standard Exceeded                                      36
# Percentage Standard Met                                           29
# Percentage Standard Met and Above                                 65
# Percentage Standard Nearly Met                                    25
# Percentage Standard Not Met                                       10
# Students with Scores                                             226
# Test Name                                                        NaN
# County Name                                                San Mateo
# District Name                      Belmont-Redwood Shores Elementary
# School Name                                        Nesbit Elementary
# Zip Code                                                       94002
# Entity Type                                            Public School
#
#                                                               304631  \
# CDS_CODE                                              41688666043475
# County Code                                                       41
# District Code                                                  68866
# School Code                                                  6043475
# Test Year                                                       2016
# Total Tested At Entity Level                                     226
# Total Tested with Scores                                         226
# Grade                                                             13
# Test Id                                                            1
# CAASPP Reported Enrollment                                       230
# Students Tested                                                  226
# Mean Scale Score                                                 NaN
# Percentage Standard Exceeded                                      37
# Percentage Standard Met                                           32
# Percentage Standard Met and Above                                 69
# Percentage Standard Nearly Met                                    17
# Percentage Standard Not Met                                       13
# Students with Scores                                             226
# Test Name                                                        NaN
# County Name                                                San Mateo
# District Name                      Belmont-Redwood Shores Elementary
# School Name                                        Nesbit Elementary
# Zip Code                                                       94002
# Entity Type                                            Public School
#
#                                                               304632  \
# CDS_CODE                                              41688666043475
# County Code                                                       41
# District Code                                                  68866
# School Code                                                  6043475
# Test Year                                                       2015
# Total Tested At Entity Level                                     160
# Total Tested with Scores                                         160
# Grade                                                              3
# Test Id                                                            1
# CAASPP Reported Enrollment                                        53
# Students Tested                                                   53
# Mean Scale Score                                              2474.9
# Percentage Standard Exceeded                                      42
# Percentage Standard Met                                           29
# Percentage Standard Met and Above                                 71
# Percentage Standard Nearly Met                                    21
# Percentage Standard Not Met                                        8
# Students with Scores                                              52
# Test Name                                                        NaN
# County Name                                                San Mateo
# District Name                      Belmont-Redwood Shores Elementary
# School Name                                        Nesbit Elementary
# Zip Code                                                       94002
# Entity Type                                            Public School
#
#                                                               304633  \
# CDS_CODE                                              41688666043475
# County Code                                                       41
# District Code                                                  68866
# School Code                                                  6043475
# Test Year                                                       2015
# Total Tested At Entity Level                                     160
# Total Tested with Scores                                         160
# Grade                                                              3
# Test Id                                                            2
# CAASPP Reported Enrollment                                        53
# Students Tested                                                   53
# Mean Scale Score                                              2480.8
# Percentage Standard Exceeded                                      37
# Percentage Standard Met                                           46
# Percentage Standard Met and Above                                 83
# Percentage Standard Nearly Met                                    10
# Percentage Standard Not Met                                        8
# Students with Scores                                              52
# Test Name                                                        NaN
# County Name                                                San Mateo
# District Name                      Belmont-Redwood Shores Elementary
# School Name                                        Nesbit Elementary
# Zip Code                                                       94002
# Entity Type                                            Public School
#
#                                                               304634  \
# CDS_CODE                                              41688666043475
# County Code                                                       41
# District Code                                                  68866
# School Code                                                  6043475
# Test Year                                                       2015
# Total Tested At Entity Level                                     160
# Total Tested with Scores                                         160
# Grade                                                              4
# Test Id                                                            2
# CAASPP Reported Enrollment                                        49
# Students Tested                                                   49
# Mean Scale Score                                              2527.6
# Percentage Standard Exceeded                                      41
# Percentage Standard Met                                           33
# Percentage Standard Met and Above                                 73
# Percentage Standard Nearly Met                                    20
# Percentage Standard Not Met                                        6
# Students with Scores                                              49
# Test Name                                                        NaN
# County Name                                                San Mateo
# District Name                      Belmont-Redwood Shores Elementary
# School Name                                        Nesbit Elementary
# Zip Code                                                       94002
# Entity Type                                            Public School
#
#                                                               304635  \
# CDS_CODE                                              41688666043475
# County Code                                                       41
# District Code                                                  68866
# School Code                                                  6043475
# Test Year                                                       2015
# Total Tested At Entity Level                                     160
# Total Tested with Scores                                         160
# Grade                                                              4
# Test Id                                                            1
# CAASPP Reported Enrollment                                        49
# Students Tested                                                   49
# Mean Scale Score                                              2534.5
# Percentage Standard Exceeded                                      51
# Percentage Standard Met                                           33
# Percentage Standard Met and Above                                 84
# Percentage Standard Nearly Met                                    12
# Percentage Standard Not Met                                        4
# Students with Scores                                              49
# Test Name                                                        NaN
# County Name                                                San Mateo
# District Name                      Belmont-Redwood Shores Elementary
# School Name                                        Nesbit Elementary
# Zip Code                                                       94002
# Entity Type                                            Public School
#
#                                                               304636  \
# CDS_CODE                                              41688666043475
# County Code                                                       41
# District Code                                                  68866
# School Code                                                  6043475
# Test Year                                                       2015
# Total Tested At Entity Level                                     160
# Total Tested with Scores                                         160
# Grade                                                              5
# Test Id                                                            1
# CAASPP Reported Enrollment                                        61
# Students Tested                                                   57
# Mean Scale Score                                              2528.9
# Percentage Standard Exceeded                                      21
# Percentage Standard Met                                           46
# Percentage Standard Met and Above                                 67
# Percentage Standard Nearly Met                                    25
# Percentage Standard Not Met                                        9
# Students with Scores                                              57
# Test Name                                                        NaN
# County Name                                                San Mateo
# District Name                      Belmont-Redwood Shores Elementary
# School Name                                        Nesbit Elementary
# Zip Code                                                       94002
# Entity Type                                            Public School
#
#                                                               304637  \
# CDS_CODE                                              41688666043475
# County Code                                                       41
# District Code                                                  68866
# School Code                                                  6043475
# Test Year                                                       2015
# Total Tested At Entity Level                                     160
# Total Tested with Scores                                         160
# Grade                                                              5
# Test Id                                                            2
# CAASPP Reported Enrollment                                        61
# Students Tested                                                   57
# Mean Scale Score                                              2533.5
# Percentage Standard Exceeded                                      25
# Percentage Standard Met                                           23
# Percentage Standard Met and Above                                 47
# Percentage Standard Nearly Met                                    40
# Percentage Standard Not Met                                       12
# Students with Scores                                              57
# Test Name                                                        NaN
# County Name                                                San Mateo
# District Name                      Belmont-Redwood Shores Elementary
# School Name                                        Nesbit Elementary
# Zip Code                                                       94002
# Entity Type                                            Public School
#
#                                                               304638  \
# CDS_CODE                                              41688666043475
# County Code                                                       41
# District Code                                                  68866
# School Code                                                  6043475
# Test Year                                                       2015
# Total Tested At Entity Level                                     160
# Total Tested with Scores                                         160
# Grade                                                             13
# Test Id                                                            2
# CAASPP Reported Enrollment                                       163
# Students Tested                                                  159
# Mean Scale Score                                                 NaN
# Percentage Standard Exceeded                                      34
# Percentage Standard Met                                           34
# Percentage Standard Met and Above                                 67
# Percentage Standard Nearly Met                                    24
# Percentage Standard Not Met                                        9
# Students with Scores                                             158
# Test Name                                                        NaN
# County Name                                                San Mateo
# District Name                      Belmont-Redwood Shores Elementary
# School Name                                        Nesbit Elementary
# Zip Code                                                       94002
# Entity Type                                            Public School
#
#                                                               304639
# CDS_CODE                                              41688666043475
# County Code                                                       41
# District Code                                                  68866
# School Code                                                  6043475
# Test Year                                                       2015
# Total Tested At Entity Level                                     160
# Total Tested with Scores                                         160
# Grade                                                             13
# Test Id                                                            1
# CAASPP Reported Enrollment                                       163
# Students Tested                                                  159
# Mean Scale Score                                                 NaN
# Percentage Standard Exceeded                                      37
# Percentage Standard Met                                           36
# Percentage Standard Met and Above                                 73
# Percentage Standard Nearly Met                                    20
# Percentage Standard Not Met                                        7
# Students with Scores                                             158
# Test Name                                                        NaN
# County Name                                                San Mateo
# District Name                      Belmont-Redwood Shores Elementary
# School Name                                        Nesbit Elementary
# Zip Code                                                       94002
# Entity Type                                            Public School
#
# [24 rows x 44 columns]
